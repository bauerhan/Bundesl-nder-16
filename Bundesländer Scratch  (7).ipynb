# %%
# Variblen definieren 
# score definieren
# Liste erstellen
Liste = ["Baden-Württemberg","Bayern","Thüringen","Sachsen","Rheinland-Pfalz","Saarland", "Hessen", "Nordrhein-Westfalen","Brandenburg","Mecklenburg-Vorpommern","Berlin","Sachsen-Anhalt","Schleswig-Holstein","Bremen","Hamburg", "Niedersachsen"]


score = 0

#Methode definieren
def scorehoch(): 
    score = score + 1
    
def scorerunter():
    score = score - 1

# %%
# nach Antwort fragen
antwort1 = input ("Wie heißt du?" + " ")

print("Hallo" + " " + antwort1)
print("Willkommen zum Erdkundeunterricht, lasst uns beginnen!")
print ("Beginnen wir mit Frage 1!")
print ("Dein score ist" + " " + str(score))
# Out:
# Wie heißt du? Martina
# Hallo Martina
# Willkommen zum Erdkundeunterricht, lasst uns beginnen!
# Beginnen wir mit Frage 1!
# Dein score ist 0

# %%
# Frage 1
from IPython.display import Image as BadenWürttemberg, display
display(BadenWürttemberg('https://paardenbed.nl/image/cache/catalog/provincies/duitsland-baden-wurtemberg-280x280.jpg', width=300, height=300))
pass


print ("Welches Bundesland siehts du?")
print ("a" + " " + str(Liste[9]))
print ("b" + " " + str(Liste[3]))
print ("c" + " " + str(Liste[0]))

antwort2 = input("Nenne deine Antwort" + " ")

if antwort2 == "c":
    print("Das ist die richitge Antwort")
    score = score + 1 
    print("Dein score ist" + " " + str(score))
    
else:
    print("Das ist leider falsch")
    score = score - 1
    print("Dein score ist" + " " + str(score))
# Out:
# Welches Bundesland siehts du?
# a Mecklenburg-Vorpommern
# b Sachsen
# c Baden-Württemberg
# Nenne deine Antwort c
# Das ist die richitge Antwort
# Dein score ist 1

# %%
#Frage 2

from IPython.display import Image as Bayern, display
display(Bayern('https://www.marktcom.de/assets/deutschlandkarte-bayern-kl-23fe10c0d69fc2a985cf08e1a4755d65003675231bcf2cc8297a36d1940af7c5.png', width=300, height=300))
pass

print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[2]))
print ("b" + " " + str(Liste[1]))
print ("c" + " " + str(Liste[6]))

antwort3 = input("Nenne deine Antwort" + " ")

if antwort3 == "b":
    print("Das ist die richitge Antwort")
    score = score + 1 
    print("Dein score ist" + " " + str(score))
    
else:
    print("Das ist leider falsch")
    score = score - 1
    print("Dein score ist" + " " + str(score))
# Out:
# Welches Bundesland ist das?
# a Thüringen
# b Bayern
# c Hessen
# Nenne deine Antwort b
# Das ist die richitge Antwort
# Dein score ist 2

# %%
#Frage 3
from IPython.display import Image as Thüringen, display
display(Thüringen('https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Locator_map_Thuringia_in_Germany.svg/757px-Locator_map_Thuringia_in_Germany.svg.png', width=300, height=300))
pass

print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[2]))
print ("b" + " " + str(Liste[0]))
print ("c" + " " + str(Liste[4]))

antwort4 = input("Nenne deine Antwort" + " ")

if antwort4 == "a":
    print("Das ist die richitge Antwort")
    score = score + 1 
    print("Dein score ist" + " " + str(score))
    
else:
    print("Das ist leider falsch")
    score = score - 1
    print("Dein score ist" + " " + str(score))
# Out:
# Welches Bundesland ist das?
# a Thüringen
# b Baden-Württemberg
# c Rheinland-Pfalz
# Nenne deine Antwort a
# Das ist die richitge Antwort
# Dein score ist 3

# %%
# Frage 4
from IPython.display import Image as Sachsen, display
display(Sachsen('https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Locator_map_Saxony_in_Germany.svg/1200px-Locator_map_Saxony_in_Germany.svg.png', width=300, height=300))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[12]))
print ("b" + " " + str(Liste[7]))
print ("c" + " " + str(Liste[3]))

antwort5 = input("Nenne deine Antwort" + " ")

if antwort5 == "c":
    print("Das ist die richitge Antwort")
    score = score + 1 
    print("Dein score ist" + " " + str(score))
    
else:
    print("Das ist leider falsch")
    score = score - 1
    print("Dein score ist" + " " + str(score))
# Out:
# Welches Bundesland ist das?
# a Schleswig-Holstein
# b Nordrhein-Westfalen
# c Sachsen
# Nenne deine Antwort c
# Das ist die richitge Antwort
# Dein score ist 4

# %%
#Bild Berlin https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Berlin/Landkarte_Berlin.png
#Bild Hamburg https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Locator_map_Hamburg_in_Germany.svg/1200px-Locator_map_Hamburg_in_Germany.svg.png
#Bild Nordrhein-westfalen https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Locator_map_North_Rhine-Westphalia_in_Germany.svg/1200px-Locator_map_North_Rhine-Westphalia_in_Germany.svg.png
#Bild Schleswig Holstein https://upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Locator_map_Schleswig-Holstein_in_Germany.svg/757px-Locator_map_Schleswig-Holstein_in_Germany.svg.png
#Bild Saarland https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Saarland/Karte_Bundesland_Saarland.png
#Bild Rheinland-Pfalz https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/Locator_map_Rhineland-Palatinate_in_Germany.svg/1200px-Locator_map_Rhineland-Palatinate_in_Germany.svg.png
#Bild Mecklenburg Vorpommern https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Locator_map_Mecklenburg-Vorpommern_in_Germany.svg/757px-Locator_map_Mecklenburg-Vorpommern_in_Germany.svg.png
#Bild Bremen https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Bremen/Landkarte_Bremen.png
#Bild Sachsen Anhalt https://upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Locator_map_Saxony-Anhalt_in_Germany.svg/757px-Locator_map_Saxony-Anhalt_in_Germany.svg.png
#Bild Hessen https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Locator_map_Hesse_in_Germany.svg/757px-Locator_map_Hesse_in_Germany.svg.png
#Bild Brandenburg https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Locator_map_Brandenburg_in_Germany.svg/757px-Locator_map_Brandenburg_in_Germany.svg.png
#Bild Niedersachsen https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Locator_map_Lower-Saxony_in_Germany.svg/1200px-Locator_map_Lower-Saxony_in_Germany.svg.png
